# %% [markdown]
# # Demo for spectral analysis functions
#
# Tom Wallis, August 2016
#
# Warning: these functions are not very robust across image sizes. Results will depend on the bandwidths and step sizes of the sliding window averaging, and this will interact with image sizes.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform
from psyutils.image import show_im
import psyutils as pu
import pycircstat as circ  # remove me
from scipy.stats import gaussian_kde

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ## Demos with an artificial edge image

# %%
# load a test image:
im = pu.im_data.orientation_test()
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (512, 512)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.502
# the SD of the image is 0.225
# the rms contrast (SD / mean) is 0.449

# %%
# show the spectrum:
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (512, 512)
# image has range from -5.823 to max 11.787
# the mean of the image is 1.156
# the SD of the image is 1.504
# the rms contrast (SD / mean) is 1.301

# %%
# take spectral power:
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %% [markdown]
# ## Test orientation mapping

# %%
x, y = pu.image.axes_cart(128)
im = np.sin(x * 8 * np.pi)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from -1.0 to max 1.0
# the mean of the image is 0.0
# the SD of the image is 0.704
# the rms contrast (SD / mean) is 1.76532140012e+16

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(A)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.0 to max 8105.88
# the mean of the image is 1.525
# the SD of the image is 90.143
# the rms contrast (SD / mean) is 59.091

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
x, y = pu.image.axes_cart(128)
im = np.sin(y * 8 * np.pi)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from -1.0 to max 1.0
# the mean of the image is -0.0
# the SD of the image is 0.704
# the rms contrast (SD / mean) is -2.03011961014e+16

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(A)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.0 to max 8105.88
# the mean of the image is 1.525
# the SD of the image is 90.143
# the rms contrast (SD / mean) is 59.091

# %%
d = pu.image.spectral_analysis(im, sf_band=1, ori_band=20)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
x, y = pu.image.axes_cart(128, angle = 45)
im = np.sin(y * 8 * np.pi)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from -1.0 to max 1.0
# the mean of the image is 0.0
# the SD of the image is 0.707
# the rms contrast (SD / mean) is 8.58439208135e+16

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(A)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.0 to max 7230.491
# the mean of the image is 6.388
# the SD of the image is 90.315
# the rms contrast (SD / mean) is 14.138

# %%
d = pu.image.spectral_analysis(im, sf_band=1, ori_band=5)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
im = pu.im_data.single_bar()
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.502
# the SD of the image is 0.277
# the rms contrast (SD / mean) is 0.553

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from -7.36 to max 9.291
# the mean of the image is -0.763
# the SD of the image is 1.884
# the rms contrast (SD / mean) is -2.47

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
# horizontal
im = transform.rotate(pu.im_data.single_bar(), 90, cval = 0.5)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.502
# the SD of the image is 0.277
# the rms contrast (SD / mean) is 0.553

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from -7.36 to max 9.291
# the mean of the image is -0.763
# the SD of the image is 1.884
# the rms contrast (SD / mean) is -2.47

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
# +45
im = transform.rotate(pu.im_data.single_bar(), 45, cval = 0.5)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.501
# the SD of the image is 0.275
# the rms contrast (SD / mean) is 0.549

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from -7.727 to max 9.291
# the mean of the image is -0.903
# the SD of the image is 1.907
# the rms contrast (SD / mean) is -2.112

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
# opposite phase:
im = transform.rotate(pu.im_data.single_bar(), 225, cval = 0.5)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.501
# the SD of the image is 0.275
# the rms contrast (SD / mean) is 0.549

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from -7.727 to max 9.291
# the mean of the image is -0.903
# the SD of the image is 1.907
# the rms contrast (SD / mean) is -2.112

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
# -45
im = transform.rotate(pu.im_data.single_bar(), -45, cval = 0.5)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.501
# the SD of the image is 0.275
# the rms contrast (SD / mean) is 0.549

# %%
A, P, F = pu.image.spectral_analysis_fft(im)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (147, 147)
# image has range from -7.727 to max 9.291
# the mean of the image is -0.903
# the SD of the image is 1.907
# the rms contrast (SD / mean) is -2.112

# %%
d = pu.image.spectral_analysis(im)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
im = pu.image.gabor_create(orientation = np.pi/2)
show_im(im.real)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (107, 107)
# image has range from -0.0 to max 0.001
# the mean of the image is 0.0
# the SD of the image is 0.0
# the rms contrast (SD / mean) is 35.897

# %%
A, P, F = pu.image.spectral_analysis_fft(im.real)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (107, 107)
# image has range from -30.63 to max -0.804
# the mean of the image is -20.351
# the SD of the image is 4.219
# the rms contrast (SD / mean) is -0.207

# %%
d = pu.image.spectral_analysis(im.real, ori_step = 1, ori_band = 10)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
im = pu.image.gabor_create(orientation = 0)
show_im(im.real)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (107, 107)
# image has range from -0.0 to max 0.001
# the mean of the image is 0.0
# the SD of the image is 0.0
# the rms contrast (SD / mean) is 35.897

# %%
A, P, F = pu.image.spectral_analysis_fft(im.real)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (107, 107)
# image has range from -30.63 to max -0.804
# the mean of the image is -20.351
# the SD of the image is 4.219
# the rms contrast (SD / mean) is -0.207

# %%
d = pu.image.spectral_analysis(im.real)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
im = pu.image.gabor_create(orientation = np.pi/4)
show_im(im.real)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (77, 77)
# image has range from -0.0 to max 0.001
# the mean of the image is 0.0
# the SD of the image is 0.0
# the rms contrast (SD / mean) is 26.459

# %%
A, P, F = pu.image.spectral_analysis_fft(im.real)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (77, 77)
# image has range from -14.327 to max -0.9
# the mean of the image is -11.249
# the SD of the image is 1.762
# the rms contrast (SD / mean) is -0.157

# %%
d = pu.image.spectral_analysis(im.real)
# plot:
pu.image.spectral_analysis_plot(d)

# %%
# test a more complex image:
im = pu.im_data.tiger_grey()
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (256, 256)
# image has range from 0.012 to max 1.0
# the mean of the image is 0.515
# the SD of the image is 0.194
# the rms contrast (SD / mean) is 0.376

# %%
A, P, F = pu.image.spectral_analysis_fft(im.real)
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (256, 256)
# image has range from -4.581 to max 10.427
# the mean of the image is 2.564
# the SD of the image is 1.053
# the rms contrast (SD / mean) is 0.411

# %%
d = pu.image.spectral_analysis(im.real)
# plot:
pu.image.spectral_analysis_plot(d)

# %% [markdown]
# ### Testing of spectral analysis function internals

# %%
im = pu.im_data.orientation_test()
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (512, 512)
# image has range from 0.0 to max 1.0
# the mean of the image is 0.502
# the SD of the image is 0.225
# the rms contrast (SD / mean) is 0.449

# %%
A, P, F = pu.image.spectral_analysis_fft(im)

# get centred grid axes:
x,y = np.meshgrid(range(A.shape[1]),range(A.shape[0]))
x = x - np.max(x)/2
y = y - np.max(y)/2

# %%
show_im(np.log(A))
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (512, 512)
# image has range from -5.823 to max 11.787
# the mean of the image is 1.156
# the SD of the image is 1.504
# the rms contrast (SD / mean) is 1.301

# %% [markdown]
# #### Test angular scan 1

# %%
angle = np.arctan2(y, -x)
angle += np.pi
show_im(angle)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (512, 512)
# image has range from 0.002 to max 6.281
# the mean of the image is 3.142
# the SD of the image is 1.805
# the rms contrast (SD / mean) is 0.574

# %%
ori_band = (np.pi / 180)*20  # convert deg to rad

mid_angle = 0.1
lower_angle = mid_angle - ori_band / 2
upper_angle = mid_angle + ori_band / 2
print(mid_angle, lower_angle, upper_angle)
mask = np.zeros(A.shape, dtype=bool)

# hacky way to get angles of wedge right. I'm sure there's a
# more sensible and easier way.
if lower_angle < 0:
        lower_angle = np.mod(lower_angle, 2 * np.pi)  # wrap
        mask[(angle >= lower_angle) *
             (angle <= (2 * np.pi))] = True
        mask[(angle <= upper_angle) *
             (angle >= 0)] = True
elif upper_angle > (2 * np.pi):
    upper_angle = np.mod(upper_angle, 2 * np.pi)  # wrap
    mask[(angle >= 0) *
         (angle <= upper_angle)] = True
    mask[(angle <= 2 * np.pi) *
         (angle >= lower_angle)] = True
else:
    mask[(angle >= lower_angle) * (angle <= upper_angle)] = True

# Do not include the zero-th frequency (overall luminance)
mask[x.shape[0]//2, y.shape[0]//2] = False

plt.imshow(mask, cmap="Greys"); plt.axis("off");
# Out:
# 0.1 -0.07453292519943294 0.27453292519943295

# %%
ori_band = (np.pi / 180)* 60  # convert deg to rad
ori_step = (np.pi / 180) * 30
finished = 0
inc = 0
ang = []
ang_amp = []
while finished == 0:
    mid_angle = 0 + inc
    lower_angle = mid_angle - ori_band / 2
    upper_angle = mid_angle + ori_band / 2
    ang.append(mid_angle)

    # create a symmetric wedge (average over edge phases):
    mask = np.zeros(A.shape, dtype=bool)

    # hacky way to get angles of wedge right. I'm sure there's a
    # more sensible and easier way.
    if lower_angle < 0:
        lower_angle = np.mod(lower_angle, 2 * np.pi)  # wrap
        mask[(angle >= lower_angle) *
             (angle <= (2 * np.pi))] = True
        mask[(angle <= upper_angle) *
             (angle >= 0)] = True
    elif upper_angle > (2 * np.pi):
        upper_angle = np.mod(upper_angle, 2 * np.pi)  # wrap
        mask[(angle >= 0) *
             (angle <= upper_angle)] = True
        mask[(angle <= 2 * np.pi) *
             (angle >= lower_angle)] = True
    else:
        mask[(angle >= lower_angle) * (angle <= upper_angle)] = True

    # Do not include the zero-th frequency (overall luminance)
    mask[x.shape[0]//2, y.shape[0]//2] = False

    # this average amplitude:
    ang_amp.append(np.mean(A[mask].flatten())/A.size)
    inc += ori_step
    if mid_angle >= (2 * np.pi):
        finished = 1

    plt.figure()
    plt.title("Inc = {} \n mid_angle = {}".format(inc, mid_angle))
    plt.imshow(mask*np.log(A)); plt.grid("off")

# %%
ax = plt.axes(projection = "polar")
ax.plot(ang, ang_amp);

# %% [markdown]
# ### Why do the vertical & horizontal sines produce different results?

# %%
x, y = pu.image.axes_cart(128)
im = np.sin(x * 8 * np.pi)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from -1.0 to max 1.0
# the mean of the image is 0.0
# the SD of the image is 0.704
# the rms contrast (SD / mean) is 1.76532140012e+16

# %%
A, P, F = pu.image.spectral_analysis_fft(im)

# get centred grid axes:
x,y = np.meshgrid(range(A.shape[1]),range(A.shape[0]))
x = x - np.max(x)/2
y = y - np.max(y)/2

# %%
show_im(A)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.0 to max 8105.88
# the mean of the image is 1.525
# the SD of the image is 90.143
# the rms contrast (SD / mean) is 59.091

# %%
angle = np.arctan2(y, -x)
angle += np.pi
show_im(angle)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.008 to max 6.275
# the mean of the image is 3.142
# the SD of the image is 1.805
# the rms contrast (SD / mean) is 0.574

# %%
ori_band = (np.pi / 180)* 60  # convert deg to rad
ori_step = (np.pi / 180) * 30
finished = 0
inc = 0
ang = []
ang_amp = []
while finished == 0:
    mid_angle = 0 + inc
    lower_angle = mid_angle - ori_band / 2
    upper_angle = mid_angle + ori_band / 2
    ang.append(mid_angle)

    # create a symmetric wedge (average over edge phases):
    mask = np.zeros(A.shape, dtype=bool)

    # hacky way to get angles of wedge right. I'm sure there's a
    # more sensible and easier way.
    if lower_angle < 0:
        lower_angle = np.mod(lower_angle, 2 * np.pi)  # wrap
        mask[(angle >= lower_angle) *
             (angle <= (2 * np.pi))] = True
        mask[(angle <= upper_angle) *
             (angle >= 0)] = True
    elif upper_angle > (2 * np.pi):
        upper_angle = np.mod(upper_angle, 2 * np.pi)  # wrap
        mask[(angle >= 0) *
             (angle <= upper_angle)] = True
        mask[(angle <= 2 * np.pi) *
             (angle >= lower_angle)] = True
    else:
        mask[(angle >= lower_angle) * (angle <= upper_angle)] = True

    # Do not include the zero-th frequency (overall luminance)
    mask[x.shape[0]//2, y.shape[0]//2] = False

    # this average amplitude:
    ang_amp.append(np.mean(A[mask].flatten())/A.size)
    inc += ori_step
    if mid_angle >= (2 * np.pi):
        finished = 1

    plt.figure()
    plt.title("Inc = {} \n mid_angle = {}".format(inc, mid_angle))
    plt.imshow(mask*np.log(A)); plt.grid("off")

# %%
x, y = pu.image.axes_cart(128)
im = np.sin(y * 8 * np.pi)
show_im(im)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from -1.0 to max 1.0
# the mean of the image is -0.0
# the SD of the image is 0.704
# the rms contrast (SD / mean) is -2.03011961014e+16

# %%
A, P, F = pu.image.spectral_analysis_fft(im)

# get centred grid axes:
x,y = np.meshgrid(range(A.shape[1]),range(A.shape[0]))
x = x - np.max(x)/2
y = y - np.max(y)/2

# %%
show_im(A)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.0 to max 8105.88
# the mean of the image is 1.525
# the SD of the image is 90.143
# the rms contrast (SD / mean) is 59.091

# %%
angle = np.arctan2(y, -x)
angle += np.pi
show_im(angle)
# Out:
# image is of type <class 'numpy.ndarray'>
# image has data type float64
# image has dimensions (128, 128)
# image has range from 0.008 to max 6.275
# the mean of the image is 3.142
# the SD of the image is 1.805
# the rms contrast (SD / mean) is 0.574

# %%
ori_band = (np.pi / 180)* 60  # convert deg to rad
ori_step = (np.pi / 180) * 30
finished = 0
inc = 0
ang = []
ang_amp = []
while finished == 0:
    mid_angle = 0 + inc
    lower_angle = mid_angle - ori_band / 2
    upper_angle = mid_angle + ori_band / 2
    ang.append(mid_angle)

    # create a symmetric wedge (average over edge phases):
    mask = np.zeros(A.shape, dtype=bool)

    # hacky way to get angles of wedge right. I'm sure there's a
    # more sensible and easier way.
    if lower_angle < 0:
        lower_angle = np.mod(lower_angle, 2 * np.pi)  # wrap
        mask[(angle >= lower_angle) *
             (angle <= (2 * np.pi))] = True
        mask[(angle <= upper_angle) *
             (angle >= 0)] = True
    elif upper_angle > (2 * np.pi):
        upper_angle = np.mod(upper_angle, 2 * np.pi)  # wrap
        mask[(angle >= 0) *
             (angle <= upper_angle)] = True
        mask[(angle <= 2 * np.pi) *
             (angle >= lower_angle)] = True
    else:
        mask[(angle >= lower_angle) * (angle <= upper_angle)] = True

    # Do not include the zero-th frequency (overall luminance)
    mask[x.shape[0]//2, y.shape[0]//2] = False

    # this average amplitude:
    ang_amp.append(np.mean(A[mask].flatten())/A.size)
    inc += ori_step
    if mid_angle >= (2 * np.pi):
        finished = 1

    plt.figure()
    plt.title("Inc = {} \n mid_angle = {}".format(inc, mid_angle))
    plt.imshow(mask*np.log(A)); plt.grid("off")

# %% [markdown]
# Can't immediately see why the horizontal frequencies would be cropped whereas the vertical are symmetric.
